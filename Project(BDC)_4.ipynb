# %% [markdown]
# # BIG DATA COMPANY - PROJECT

# %% [markdown]
# ### Group members:
#
# Moritz Scheer
#
# Yuzhe Wang
#
# Zongyi Guo
#
# Gryy

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.linear_model as lm

# %% [markdown]
# ### Importing data

# %%
#df_original = pd.read_csv('dataport-export_gas_oct2015-mar2016.csv')
df_original = pd.read_csv('practice.csv')

# %%
df_original.head()
# Out:
#               localminute  dataid  meter_value
# 0  2015-10-01 00:00:10-05     739        88858
# 1  2015-10-01 00:00:13-05    8890       197164
# 2  2015-10-01 00:00:20-05    6910       179118
# 3  2015-10-01 00:00:22-05    3635       151318
# 4  2015-10-01 00:00:22-05    1507       390354

# %%
df_original.tail()
# Out:
#                   localminute  dataid  meter_value
# 65529  2015-10-08 14:18:56-05    8829       156062
# 65530  2015-10-08 14:19:04-05    9295       158054
# 65531  2015-10-08 14:19:10-05    4514       382540
# 65532  2015-10-08 14:19:18-05      77        58982
# 65533  2015-10-08 14:19:20-05    9052       297730

# %%
df_original.dtypes
# Out:
# localminute    object
# dataid          int64
# meter_value     int64
# dtype: object

# %% [markdown]
# ### Optimizing Data Framework

# %%
df = df_original  #duplicated or still same object?
df.columns = ['date', 'id', 'measurement']
df.head()
# Out:
#                      date    id  measurement
# 0  2015-10-01 00:00:10-05   739        88858
# 1  2015-10-01 00:00:13-05  8890       197164
# 2  2015-10-01 00:00:20-05  6910       179118
# 3  2015-10-01 00:00:22-05  3635       151318
# 4  2015-10-01 00:00:22-05  1507       390354

# %%
year = []
month = []
day = []
hour = []
minute = []
sec = []
absolute_sec = []


for i in range (len(df.date)):
    str_object = df.at[i, 'date']
    year.append(int(str_object[:4]))
    month.append(int(str_object[5:7]))
    day.append(int(str_object[8:10]))
    hour.append(int(str_object[11:13]))
    minute.append(int(str_object[14:16]))
    sec.append(int(str_object[17:19]))
    
    abs_sec = sec[i] + 60*minute[i] + 60*60*hour[i] + 24*60*60*(day[i] - 1)  
    if (month[i] == 10):   
        abs_sec += 0
    elif (month[i] == 11):
        abs_sec += 31*24*60*60
    elif (month[i] == 12):
        abs_sec += (30+31)*24*60*60
    elif (month[i] == 1):
        abs_sec += (31+30+31)*24*60*60
    elif (month[i] == 2):
        abs_sec += (31+31+30+31)*24*60*60
    elif (month[i] == 3):
        abs_sec += (29+31+31+30+31)*24*60*60
    absolute_sec.append(abs_sec) 
    

df.insert(1, 'year', year, allow_duplicates = True)
df.insert(2, 'month', month, allow_duplicates = True)
df.insert(3, 'day', day, allow_duplicates = True)
df.insert(4, 'hour', hour, allow_duplicates = True)
df.insert(5, 'minute', minute, allow_duplicates = True)
df.insert(6, 'sec', sec, allow_duplicates = True)
df.insert(7, 'absolute_sec', absolute_sec, allow_duplicates = True)

# %%
df.head()
# Out:
#                      date  year  month  day  hour  minute  sec  absolute_sec  \
# 0  2015-10-01 00:00:10-05  2015     10    1     0       0   10            10
# 1  2015-10-01 00:00:13-05  2015     10    1     0       0   13            13
# 2  2015-10-01 00:00:20-05  2015     10    1     0       0   20            20
# 3  2015-10-01 00:00:22-05  2015     10    1     0       0   22            22
# 4  2015-10-01 00:00:22-05  2015     10    1     0       0   22            22
#
#      id  measurement
# 0   739        88858
# 1  8890       197164
# 2  6910       179118
# 3  3635       151318
# 4  1507       390354

# %%
df.tail()
# Out:
#                          date  year  month  day  hour  minute  sec  \
# 65529  2015-10-08 14:18:56-05  2015     10    8    14      18   56
# 65530  2015-10-08 14:19:04-05  2015     10    8    14      19    4
# 65531  2015-10-08 14:19:10-05  2015     10    8    14      19   10
# 65532  2015-10-08 14:19:18-05  2015     10    8    14      19   18
# 65533  2015-10-08 14:19:20-05  2015     10    8    14      19   20
#
#        absolute_sec    id  measurement
# 65529        656336  8829       156062
# 65530        656344  9295       158054
# 65531        656350  4514       382540
# 65532        656358    77        58982
# 65533        656360  9052       297730

# %%
df.dtypes
# Out:
# date            object
# year             int64
# month            int64
# day              int64
# hour             int64
# minute           int64
# sec              int64
# absolute_sec     int64
# id               int64
# measurement      int64
# dtype: object

# %% [markdown]
# ### 1.1 Number of households

# %%
len(set(df.id))
# Out:
# 127

# %% [markdown]
# There are 157 different households included in our data set of the measurement study.

# %% [markdown]
# ### 1.1 Malfunctioning meters

# %%
#Code for finding and elimintaing malfunctioning meters

#datadframework should be same only without malfunctioning meters

# %% [markdown]
# ### 1.2 Hourly readings

# %% [markdown]
# #### Helpful functions

# %%
def getID (df, id):
    df_id = pd.DataFrame({'date': [], 
                          'year': [],
                            'month': [],
                             'day': [],
                            'hour': [],
                            'minute': [],
                            'sec': [],
                          'absolute_sec': [],
                         'id': [],
                         'measurement': []})
    
    for i in range (len(df)):                 
        if df.at[i, 'id'] == id:
            df_id = df_id.append(df.iloc[i, :])
            
    return df_id

# %%
def getMonth (df, month):
    df_month = pd.DataFrame({'date': [], 
                          'year': [],
                            'month': [],
                             'day': [],
                            'hour': [],
                            'minute': [],
                            'sec': [],
                             'absolute_sec': [],
                         'id': [],
                         'measurement': []})
    
    for i in range (len(df)):                    #changed 30*24 back to len(df)
        if df.at[i, 'month'] == month:
            df_month = df_month.append(df.iloc[i, :])
            
    return df_month

# %%
def getIDandMonth (df, id, month):
    df_id_month = pd.DataFrame({'date': [], 
                          'year': [],
                            'month': [],
                             'day': [],
                            'hour': [],
                            'minute': [],
                            'sec': [],
                          'absolute_sec': [],
                         'id': [],
                         'measurement': []})
    
    for i in range (len(df)):              
        if df.at[i, 'id'] == id and df.at[i, 'month'] == month:
            df_id_month = df_id_month.append(df.iloc[i, :])
            
    return df_id_month

# %% [markdown]
# #### Selecting best month

# %% [markdown]
# Choosing month with most data samples as best month.

# %% [raw]
# df_october = getMonth(df, 10)
# df_november = getMonth(df, 11)
# df_december = getMonth(df, 12)
# df_january = getMonth(df, 1)
# df_febuary = getMonth(df, 2)
# df_march = getMonth(df, 3)

# %% [raw]
# x = ['October', 'November', 'December', 'January', 'Febuary', 'March']
# y = [len(df_october), len(df_november), len(df_december), len(df_january), len(df_febuary), len(df_march)]
#
# index = np.arange(len(x))
# plt.bar(x, y)
# plt.xlabel('Month')
# plt.ylabel('Data samples')
# plt.title('Data samples per month')
# plt.show()

# %%
def findBestMonth(df):
    samples_per_month = [len(getMonth(df, 10)), len(getMonth(df, 11)), len(getMonth(df, 12)), 
                         len(getMonth(df, 1)), len(getMonth(df, 2)), len(getMonth(df, 3))]
    months = [10, 11, 12, 1, 2, 3]
    
    return months[samples_per_month.index(max(samples_per_month))]

# %% [markdown]
# #### Getting hourly readings

# %%
from scipy import interpolate

def hourlyReadings_IDandMonth(df, id, month):
    df_correct = getIDandMonth(df, id, month)
    
    x = df_correct.absolute_sec
    y = df_correct.measurement
    
    tck = interpolate.splrep(x, y)
    
    hourly_readings = []
    if month == 10 or month == 12 or moth == 1 or month == 3:
        for i in range (31*24):
            hourly_readings.append(interpolate.splev(i*60^2, tck))
    elif month == 11:
        for i in range (30*24):
            hourly_readings.append(interpolate.splev(i*60^2, tck))
    elif month == 2:
        for i in range (29*24):
            hourly_readings.append(interpolate.splev(i*60^2, tck))
        
    return hourly_readings

# %%
def hourlyReadings_Month(df, month):
    hourly_readings_month = {}

    for x in set(df.id):           #manche ids produzieren wohl Fehler "m > k must hold"
        hourly_readings_month[x] = hourlyReadings_IDandMonth(df, x, bm)
        
    return hourly_readings_month

#hourlyReadings(df, 8890, 10)   warum nan nan?

# %% [markdown]
# #### Hourly readings of random households for best month (5x)

# %%
def plottingOneID(df, id, month):
    if month == 10 or month == 12 or month == 1 or month == 3:
        x = range(0, 31*24)
    elif month == 11:
        x = range(0, 30*24)
    elif month == 2:
        x = range(0, 29*24)

    y = hourlyReadings_IDandMonth(df, id, month)
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.plot(x, y, '--k')
    ax.set_xlim(0, 31*24)
    ax.set_title('Hourly reading of Household {} for month {}'.format(id, month))
    plt.xlabel("Hour")
    plt.ylabel("Measurement")
    plt.grid()

# %%
import random

bm = 10 #change to findBestMonth

plottingOneID(df, random.sample(set(df.id),  1), bm)

# %%
plottingOneID(df, random.sample(set(df.id),  1), bm)

# %%
plottingOneID(df, random.sample(set(df.id),  1), bm)

# %%
plottingOneID(df, random.sample(set(df.id),  1), bm)

# %%
plottingOneID(df, random.sample(set(df.id),  1), bm)

# %% [markdown]
# #### Hourly readings of 3 random households for best month

# %%
def plottingThreeID(df, ids, month):
    if month == 10 or month == 12 or month == 1 or month == 3:
        x = range(0, 31*24)
    elif month == 11:
        x = range(0, 30*24)
    elif month == 2:
        x = range(0, 29*24)

    y1 = hourlyReadings_IDandMonth(df, ids[0], month)  
    y2 = hourlyReadings_IDandMonth(df, ids[1], month)
    y3 = hourlyReadings_IDandMonth(df, ids[2], month)
    
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.plot(x, y1, '--k', label = ids[0])
    ax.plot(x, y2, '-', label = ids[1])
    ax.plot(x, y3, '-.', label = ids[2])
    ax.legend()
    ax.set_xlim(0, 31*24)
    ax.set_title('Hourly reading for month {}'.format(month))
    plt.xlabel("Hour")
    plt.ylabel("Measurement")
    plt.grid()
    plt.show()

# %%
plottingThreeID(df, random.sample(set(df.id),  3), 10)

# %% [markdown]
# When plotting multiple households in the same plot, it looks like all three of them are steady since the small changes are not visible due to the different starting values.

# %% [markdown]
# #### Hourly readings, resetted to 0 at beginning of month, of 3 random households for best month (5x)

# %%
def plottingChangesThreeID(df, ids, month):
    if month == 10 or month == 12 or month == 1 or month == 3:
        x = range(0, 31*24)
    elif month == 11:
        x = range(0, 30*24)
    elif month == 2:
        x = range(0, 29*24)

    y1 = hourlyReadings_IDandMonth(df, ids[0], month)  
    y2 = hourlyReadings_IDandMonth(df, ids[1], month)
    y3 = hourlyReadings_IDandMonth(df, ids[2], month)
    
    y = [y1, y2, y3]
    
    for y_i in y:
        too_much = y_i[0]
        for j in range (len(y_i)):
            y_i[j] = y_i[j] - too_much
        print(too_much)
            
    y1 = y[0]
    y2 = y[1]
    y3 = y[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.plot(x, y1, '--k', label = ids[0])
    ax.plot(x, y2, '-', label = ids[1])
    ax.plot(x, y3, '-.', label = ids[2])
    ax.legend()
    ax.set_xlim(0, 31*24)
    ax.set_title('Hourly reading for month {}'.format(month))
    plt.xlabel("Hour")
    plt.ylabel("Measurement")
    plt.grid()
    plt.show()

# %%
plottingChangesThreeID(df, random.sample(set(df.id),  3), 10)
# Out:
# 178785.73375883055
# 172122.8812402149
# 209233.00450266525

# %%
plottingChangesThreeID(df, random.sample(set(df.id),  3), 10)
# Out:
# 190042.2780537162
# 181516.0920300719
# 58831.99999838556

# %%
plottingChangesThreeID(df, random.sample(set(df.id),  3), 10)
# Out:
# 123020.00031845203
# 193610.03081640127
# 149757.6459745933

# %%
plottingChangesThreeID(df, random.sample(set(df.id),  3), 10)
# Out:
# 390354.00000000006
# 91759.9989719431
# 178785.73375883055

# %%
plottingChangesThreeID(df, random.sample(set(df.id),  3), 10)
# Out:
# 193921.9999982235
# 106464.00000000001
# 147047.9999999999

# %% [markdown]
# When just plotting the measurements given by the meters, the values of different homes differ so much that the changes become invisible in a graph with multiple households. This is due to the fact that all household have a very different threshold, probably because the meters were installed at different times.
# When plotting just the changes, meaning removing the threshold of the given values or resetting the meters value to zero at the beginning of the month, they become easily visible.

# %% [markdown]
# #### Average, resetted hourly readings for best month

# %%
def plottingAverageChanges(df, month):
    if month == 10 or month == 12 or month == 1 or month == 3:
        x = range(0, 31*24)
    elif month == 11:
        x = range(0, 30*24)
    elif month == 2:
        x = range(0, 29*24)

    y = hourlyReadings_Month(df, month) 
    
    for key in y.keys():
        too_much = y.get(key)[0]
        for j in range (len(y_i)):
            y.get(key)[j] -= too_much
        
    average_y = []
    
    for j in range (len(y.get(random.sample(y.values(), 1)))):
        average_y[j] = 0
        for key in y.keys(): 
            average_y[j] += y.get(key)[j]
        average_y[j] /= len(y.get(random.sample(y.values(), 1)))
            
    y1 = y[0]
    y2 = y[1]
    y3 = y[2]
    
    fig, ax = plt.subplots(1, 1, figsize=(12, 8))
    ax.plot(x, y1, '--k', x, y2, '-', x, y3, '-.')
    ax.set_xlim(0, 31*24)
    ax.set_title('Hourly reading for month {}'.format(month))
    plt.xlabel("Hour")
    plt.ylabel("Measurement")
    plt.grid()
    plt.show()

# %%
plottingAverageChanges(df, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-fd1e68952440> in <module>
# ----> 1 plottingAverageChanges(df, 10)
#
# <ipython-input-75-22918699e51d> in plottingAverageChanges(df, month)
#       7         x = range(0, 29*24)
#       8
# ----> 9     y = hourlyReadings_Month(df, month)
#      10
#      11     for key in y.keys():
#
# <ipython-input-79-f192a5054ae9> in hourlyReadings_Month(df, month)
#       3
#       4     for x in set(df.id):           #manche ids produzieren wohl Fehler "m > k must hold"
# ----> 5         hourly_readings_month[x] = hourlyReadings_IDandMonth(df, x, bm)
#       6
#       7     return hourly_readings_month
#
# <ipython-input-17-240f269be8d9> in hourlyReadings_IDandMonth(df, id, month)
#       7     y = df_correct.measurement
#       8
# ----> 9     tck = interpolate.splrep(x, y)
#      10
#      11     hourly_readings = []
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/interpolate/fitpack.py in splrep(x, y, w, xb, xe, k, task, s, t, full_output, per, quiet)
#     287
#     288     """
# --> 289     res = _impl.splrep(x, y, w, xb, xe, k, task, s, t, full_output, per, quiet)
#     290     return res
#     291
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/interpolate/_fitpack_impl.py in splrep(x, y, w, xb, xe, k, task, s, t, full_output, per, quiet)
#     462                         '(1<=k<=5)' % k)
#     463     if m <= k:
# --> 464         raise TypeError('m > k must hold')
#     465     if xb is None:
#     466         xb = x[0]
#
# TypeError: m > k must hold
